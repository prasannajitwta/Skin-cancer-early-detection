# %% [markdown]
# # Importing Essential Libraries

# %%
import numpy as np
import pandas as pd
import os
import sys
from glob import glob
import tensorflow.keras
from tensorflow.python.keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from PIL import Image
np.random.seed(123)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data processing

# %%
base_skin_dir = os.path.join('C:/Users/Pavithra/Desktop/fyop', 'archive')

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                   for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}

lesion_dict = {     
                  'nv': 'Melanocytic nevi',
                  'mel': 'Melanoma',
                  'bkl': 'Benign keratosis-like lesions ',
                  'bcc': 'Basal cell carcinoma',
                  'akiec': 'Actinic keratoses',
                  'vasc': 'Vascular lesions',
                  'df': 'Dermatofibroma'
              }

# %% [markdown]
# # Reading Dataset and adding new columns:

# %%
print("Reading Dataset and adding new columns:")

dataset = pd.read_csv('HAM10000_metadata.csv')

dataset['path'] = dataset['image_id'].map(imageid_path_dict.get)
dataset['cell_type'] = dataset['dx'].map(lesion_dict.get)
dataset['cell_codes'] = pd.Categorical(dataset['cell_type']).codes
# Out:
# Reading Dataset and adding new columns:

# %%
dataset.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path  \
# 0  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 1  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 2  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 3  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 4  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
#
#                         cell_type  cell_codes
# 0  Benign keratosis-like lesions            2
# 1  Benign keratosis-like lesions            2
# 2  Benign keratosis-like lesions            2
# 3  Benign keratosis-like lesions            2
# 4  Benign keratosis-like lesions            2

# %% [markdown]
# # Data Cleaning

# %%
dataset.isnull().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age             57
# sex              0
# localization     0
# path             0
# cell_type        0
# cell_codes       0
# dtype: int64

# %%
dataset['age'].fillna((dataset['age'].mean()), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# lesion_id       0
# image_id        0
# dx              0
# dx_type         0
# age             0
# sex             0
# localization    0
# path            0
# cell_type       0
# cell_codes      0
# dtype: int64

# %% [markdown]
# # Visualisations

# %%
def DIE():
    
    from IPython.display import HTML
    from IPython.display import display

    tag = HTML('''<script>
    code_show=true; 
    function code_toggle() 
    {
        if (code_show)
        {
            $('div.cell.code_cell.rendered.selected div.input').hide();
        } else 
        {
            $('div.cell.code_cell.rendered.selected div.input').show();
        }
        code_show = !code_show
    } 
    $( document ).ready(code_toggle);
    </script>
    <a href="javascript:code_toggle()">CODE</a>.''')
    display(tag)
DIE()
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Cell type count bar diagram

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize = (20, 10))
dataset['cell_type'].value_counts().plot(kind='bar', ax = ax1)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# # Method count bar diagram

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (20, 10))
dataset['dx_type'].value_counts().plot(kind='bar')
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# # Region count bar diagram

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (25, 15))
dataset['localization'].value_counts().plot(kind='bar')
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# # Age count histogram

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (25, 15))
dataset['age'].hist(bins=40)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# # Cell type count histogram

# %%
DIE()
fig, ax1 = plt.subplots(1, 1, figsize= (25, 15))
dataset['cell_codes'].hist(bins=40)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.
# <AxesSubplot:>

# %% [markdown]
# # Resizing the images

# %%
dataset['image'] = dataset['path'].map(lambda x: np.asarray(Image.open(x).resize((64,64))))

# %%
dataset['image'] = dataset['path'].map(lambda x: np.asarray(Image.open(x).resize((64,64))))

# %%
dataset.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path  \
# 0  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 1  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 2  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 3  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
# 4  C:/Users/Pavithra/Desktop/fyop\archive\HAM1000...
#
#                         cell_type  cell_codes  \
# 0  Benign keratosis-like lesions            2
# 1  Benign keratosis-like lesions            2
# 2  Benign keratosis-like lesions            2
# 3  Benign keratosis-like lesions            2
# 4  Benign keratosis-like lesions            2
#
#                                                image
# 0  [[[191, 152, 194], [191, 153, 195], [192, 149,...
# 1  [[[23, 13, 23], [25, 14, 28], [37, 24, 46], [6...
# 2  [[[186, 129, 140], [192, 136, 151], [198, 143,...
# 3  [[[24, 11, 19], [36, 20, 30], [64, 38, 50], [9...
# 4  [[[139, 95, 118], [158, 114, 138], [178, 133, ...

# %% [markdown]
# # Displaying Samples

# %%
DIE()
import matplotlib.pyplot as plt
fig, m_axs = plt.subplots(7, 4, figsize = (4*4, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs,dataset.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(7, random_state=1).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %% [markdown]
# # Selecting the features and targets

# %%
features=dataset.drop(columns=['cell_codes'],axis=1)
target=dataset['cell_codes']

# %% [markdown]
# # Train test splitting

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(features, target, test_size=0.20,random_state=2)

# %% [markdown]
# # Normalising the training set

# %% [markdown]
# ##### Normalisation reduces data redundancy.It is a process to eliminate the flaws of a database with bad design. A poorly designed database is inconsistent and create issues while adding, deleting or updating information.

# %%
x_train = np.asarray(x_train1['image'].tolist())
x_test = np.asarray(x_test1['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_test_mean)/x_test_std

# %% [markdown]
# # Performing one-hot encoding on the labels

# %%
y_train = to_categorical(y_train1, num_classes = 7)
y_test = to_categorical(y_test1, num_classes = 7)

# %% [markdown]
# # Validation and training set splitting

# %%
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.1, random_state = 2)

# %% [markdown]
# # Reshaping image in 4 dimensions

# %%
x_train = x_train.reshape(x_train.shape[0], *(64, 64, 3))
x_test = x_test.reshape(x_test.shape[0], *(64, 64, 3))
x_validate = x_validate.reshape(x_validate.shape[0], *(64, 64, 3))

# %% [markdown]
# # CNN
# USING KERAS TENSORFLOW IN BACKEND
#
# In this model, we first appply different feature detectors or kernels onto the input image to get the first two convoled layers then we apply Max Pooling to get the max pooled layer and similiarly we obtain the next layers and finally we obtain the Flatten layer using Flatten(). Then the fully connected layers(hidden layers) to finally give the output layer of 7 neurons.
#
# title

# %%
shape = (64, 64, 3)

classifier = Sequential()
classifier.add(Conv2D(32, (3, 3), activation='relu',input_shape=shape))
classifier.add(Conv2D(32, (3, 3), activation='relu'))
classifier.add(MaxPool2D(pool_size = (2, 2)))
classifier.add(Dropout(0.05))

classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(Conv2D(64, (3, 3), activation='relu'))
classifier.add(MaxPool2D(pool_size=(2, 2)))
classifier.add(Dropout(0.10))

classifier.add(Flatten())

classifier.add(Dense(128, activation='relu'))
classifier.add(Dropout(0.15))
classifier.add(Dense(64, activation='relu'))

classifier.add(Dense(32, activation='relu'))
classifier.add(Dropout(0.20))

classifier.add(Dense(7, activation='softmax'))
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 13, 13, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 10816)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               1384576
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 231
# =================================================================
# Total params: 1,460,711
# Trainable params: 1,460,711
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compiling the model

# %%
classifier.compile(optimizer = 'adam' , loss = "categorical_crossentropy", metrics=["accuracy"])

# %% [markdown]
# # Categorical Cross Entropy
#
# Categorical cross entropy is a Softmax activation plus a Cross-Entropy loss. While using this loss, we train a CNN to output a probability over the C classes for each image. It is used for multi-class classification.
#
# title

# %%
datagen = ImageDataGenerator(
                            featurewise_std_normalization=False, 
                            samplewise_std_normalization=False, 
                            rotation_range=10, 
                            zoom_range = 0.1,  
                            width_shift_range=0.1,
                            height_shift_range=0.1,
                            horizontal_flip=False,  
                            vertical_flip=False
                            )
datagen.fit(x_train)

# %% [markdown]
# # Fitting the model

# %%
epochs = 50
batch_size = 10
history = classifier.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_validate,y_validate),
                              steps_per_epoch=x_train.shape[0] // batch_size)
# Out:
# c:\users\pavithra\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\keras\engine\training.py:1935: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 721/721 [==============================] - 156s 183ms/step - loss: 1.0577 - accuracy: 0.6614 - val_loss: 0.8726 - val_accuracy: 0.6858
# Epoch 2/50
# 721/721 [==============================] - 131s 182ms/step - loss: 0.9329 - accuracy: 0.6687 - val_loss: 0.8240 - val_accuracy: 0.6858
# Epoch 3/50
# 721/721 [==============================] - 132s 184ms/step - loss: 0.8809 - accuracy: 0.6840 - val_loss: 0.7905 - val_accuracy: 0.7145
# Epoch 4/50
# 721/721 [==============================] - 139s 193ms/step - loss: 0.8526 - accuracy: 0.6957 - val_loss: 0.7440 - val_accuracy: 0.7170
# Epoch 5/50
# 721/721 [==============================] - 139s 192ms/step - loss: 0.8229 - accuracy: 0.7003 - val_loss: 0.7787 - val_accuracy: 0.7369
# Epoch 6/50
# 721/721 [==============================] - 131s 182ms/step - loss: 0.7988 - accuracy: 0.7051 - val_loss: 0.7174 - val_accuracy: 0.7344
# Epoch 7/50
# 721/721 [==============================] - 130s 181ms/step - loss: 0.7981 - accuracy: 0.7044 - val_loss: 0.7001 - val_accuracy: 0.7332
# Epoch 8/50
# 721/721 [==============================] - 129s 179ms/step - loss: 0.7800 - accuracy: 0.7148 - val_loss: 0.7558 - val_accuracy: 0.7170
# Epoch 9/50
# 721/721 [==============================] - 128s 177ms/step - loss: 0.7647 - accuracy: 0.7186 - val_loss: 0.7139 - val_accuracy: 0.7282
# Epoch 10/50
# 721/721 [==============================] - 129s 178ms/step - loss: 0.7628 - accuracy: 0.7204 - val_loss: 0.7353 - val_accuracy: 0.7219
# Epoch 11/50
# 721/721 [==============================] - 129s 178ms/step - loss: 0.7448 - accuracy: 0.7233 - val_loss: 0.6672 - val_accuracy: 0.7431
# Epoch 12/50
# 721/721 [==============================] - 128s 178ms/step - loss: 0.7315 - accuracy: 0.7330 - val_loss: 0.7072 - val_accuracy: 0.7456
# Epoch 13/50
# 721/721 [==============================] - 129s 179ms/step - loss: 0.7272 - accuracy: 0.7352 - val_loss: 0.6788 - val_accuracy: 0.7419
# Epoch 14/50
# 721/721 [==============================] - 128s 177ms/step - loss: 0.7138 - accuracy: 0.7379 - val_loss: 0.7260 - val_accuracy: 0.7419
# Epoch 15/50
# 721/721 [==============================] - 128s 177ms/step - loss: 0.7172 - accuracy: 0.7377 - val_loss: 0.7346 - val_accuracy: 0.7282
# Epoch 16/50
# 721/721 [==============================] - 128s 178ms/step - loss: 0.7072 - accuracy: 0.7431 - val_loss: 0.6763 - val_accuracy: 0.7444
# Epoch 17/50
# 721/721 [==============================] - 129s 179ms/step - loss: 0.7097 - accuracy: 0.7430 - val_loss: 0.6604 - val_accuracy: 0.7606
# Epoch 18/50
# 721/721 [==============================] - 128s 178ms/step - loss: 0.7349 - accuracy: 0.7405 - val_loss: 0.6729 - val_accuracy: 0.7531
# Epoch 19/50
# 721/721 [==============================] - 129s 179ms/step - loss: 0.6889 - accuracy: 0.7481 - val_loss: 0.6774 - val_accuracy: 0.7544
# Epoch 20/50
# 721/721 [==============================] - 129s 179ms/step - loss: 0.6942 - accuracy: 0.7499 - val_loss: 0.6587 - val_accuracy: 0.7656
# Epoch 21/50
# 721/721 [==============================] - 128s 178ms/step - loss: 0.6788 - accuracy: 0.7524 - val_loss: 0.6577 - val_accuracy: 0.7594
# Epoch 22/50
# 721/721 [==============================] - 128s 178ms/step - loss: 0.6695 - accuracy: 0.7498 - val_loss: 0.6608 - val_accuracy: 0.7544
# Epoch 23/50
# 721/721 [==============================] - 128s 178ms/step - loss: 0.6752 - accuracy: 0.7535 - val_loss: 0.6506 - val_accuracy: 0.7494
# Epoch 24/50
# 721/721 [==============================] - 129s 179ms/step - loss: 0.6641 - accuracy: 0.7594 - val_loss: 0.6694 - val_accuracy: 0.7506
# Epoch 25/50
# 721/721 [==============================] - 129s 178ms/step - loss: 0.6585 - accuracy: 0.7614 - val_loss: 0.6238 - val_accuracy: 0.7569
# Epoch 26/50
# 721/721 [==============================] - 129s 178ms/step - loss: 0.6453 - accuracy: 0.7628 - val_loss: 0.6460 - val_accuracy: 0.7643
# Epoch 27/50
# 721/721 [==============================] - 131s 181ms/step - loss: 0.6456 - accuracy: 0.7610 - val_loss: 0.6633 - val_accuracy: 0.7706
# Epoch 28/50
# 721/721 [==============================] - 140s 194ms/step - loss: 0.6518 - accuracy: 0.7577 - val_loss: 0.6353 - val_accuracy: 0.7743
# Epoch 29/50
# 721/721 [==============================] - 127s 177ms/step - loss: 0.6256 - accuracy: 0.7696 - val_loss: 0.6715 - val_accuracy: 0.7656
# Epoch 30/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.6277 - accuracy: 0.7698 - val_loss: 0.6208 - val_accuracy: 0.7681
# Epoch 31/50
# 721/721 [==============================] - 125s 173ms/step - loss: 0.6206 - accuracy: 0.7721 - val_loss: 0.7105 - val_accuracy: 0.7544
# Epoch 32/50
# 721/721 [==============================] - 124s 172ms/step - loss: 0.6141 - accuracy: 0.7750 - val_loss: 0.6318 - val_accuracy: 0.7706
# Epoch 33/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.6084 - accuracy: 0.7810 - val_loss: 0.6270 - val_accuracy: 0.7731
# Epoch 34/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5968 - accuracy: 0.7798 - val_loss: 0.7019 - val_accuracy: 0.7519
# Epoch 35/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.6293 - accuracy: 0.7720 - val_loss: 0.6308 - val_accuracy: 0.7718
# Epoch 36/50
# 721/721 [==============================] - 126s 174ms/step - loss: 0.5961 - accuracy: 0.7847 - val_loss: 0.6817 - val_accuracy: 0.7594
# Epoch 37/50
# 721/721 [==============================] - 124s 171ms/step - loss: 0.5938 - accuracy: 0.7824 - val_loss: 0.6623 - val_accuracy: 0.7731
# Epoch 38/50
# 721/721 [==============================] - 124s 171ms/step - loss: 0.5860 - accuracy: 0.7881 - val_loss: 0.6227 - val_accuracy: 0.7781
# Epoch 39/50
# 721/721 [==============================] - 124s 172ms/step - loss: 0.6045 - accuracy: 0.7840 - val_loss: 0.6182 - val_accuracy: 0.7756
# Epoch 40/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5903 - accuracy: 0.7852 - val_loss: 0.7061 - val_accuracy: 0.7606
# Epoch 41/50
# 721/721 [==============================] - 123s 170ms/step - loss: 0.5811 - accuracy: 0.7967 - val_loss: 0.6293 - val_accuracy: 0.7793
# Epoch 42/50
# 721/721 [==============================] - 124s 171ms/step - loss: 0.5737 - accuracy: 0.7940 - val_loss: 0.6641 - val_accuracy: 0.7668
# Epoch 43/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5905 - accuracy: 0.7835 - val_loss: 0.6285 - val_accuracy: 0.7731
# Epoch 44/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5720 - accuracy: 0.7868 - val_loss: 0.6333 - val_accuracy: 0.7793
# Epoch 45/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5762 - accuracy: 0.7965 - val_loss: 0.6524 - val_accuracy: 0.7668
# Epoch 46/50
# 721/721 [==============================] - 124s 172ms/step - loss: 0.5606 - accuracy: 0.7926 - val_loss: 0.6505 - val_accuracy: 0.7556
# Epoch 47/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5565 - accuracy: 0.7967 - val_loss: 0.6836 - val_accuracy: 0.7569
# Epoch 48/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5636 - accuracy: 0.7967 - val_loss: 0.6246 - val_accuracy: 0.7531
# Epoch 49/50
# 721/721 [==============================] - 123s 171ms/step - loss: 0.5504 - accuracy: 0.7956 - val_loss: 0.6605 - val_accuracy: 0.7681
# Epoch 50/50
# 721/721 [==============================] - 126s 174ms/step - loss: 0.5594 - accuracy: 0.7963 - val_loss: 0.6244 - val_accuracy: 0.7768

# %% [markdown]
# # Calculating validation set and test set accuracies

# %%
loss, accuracy = classifier.evaluate(x_test, y_test)
loss_v, accuracy_v = classifier.evaluate(x_validate, y_validate)
print("Validation: accuracy = %f  ;  loss_v = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
classifier.save("classify.h5")
# Out:
# 63/63 [==============================] - 8s 128ms/step - loss: 0.6920 - accuracy: 0.7644
# 26/26 [==============================] - 3s 113ms/step - loss: 0.6244 - accuracy: 0.7768
# Validation: accuracy = 0.776808  ;  loss_v = 0.624435
# Test: accuracy = 0.764353  ;  loss = 0.691956

# %% [markdown]
# # Plotting model's validation loss and validation accuracy

# %%
DIE()
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %%
plot_model_history(history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10108/2677778347.py in <module>
# ----> 1 plot_model_history(history)
#       2
#       3
#
# ~\AppData\Local\Temp/ipykernel_10108/4176374837.py in plot_model_history(model_history)
#       8     axs[0].set_ylabel('Accuracy')
#       9     axs[0].set_xlabel('Epoch')
# ---> 10     axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
#      11     axs[0].legend(['train', 'val'], loc='best')
#      12     # summarize history for loss
#
# c:\users\pavithra\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# TypeError: set_ticks() takes 2 positional arguments but 3 were given

# %% [markdown]
# # Confusion Matrix

# %%
DIE()
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    decoy = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > decoy else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Predicting the values from the validation dataset
Y_pred = classifier.predict(x_validate)
#Converting predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
#Converting validation observations to one hot vectors
Y_true = np.argmax(y_validate,axis = 1) 
#Computing the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

plot_confusion_matrix(confusion_mtx, classes = range(7))
# Out:
# <script>
#     code_show=true;
#     function code_toggle()
#     {
#         if (code_show)
#         {
#             $('div.cell.code_cell.rendered.selected div.input').hide();
#         } else
#         {
#             $('div.cell.code_cell.rendered.selected div.input').show();
#         }
#         code_show = !code_show
#     }
#     $( document ).ready(code_toggle);
#     </script>
#     <a href="javascript:code_toggle()">CODE</a>.

# %%
from keras.preprocessing import image
test_image1 = image.load_img('C:/Users/Pavithra/Desktop/test2.jpg', target_size = (64, 64))
test_image1 = image.img_to_array(test_image1)
test_image1 = np.expand_dims(test_image1, axis = 0)
result = classifier.predict(test_image1)
if result[0][0] == 1:
    print('TYPE:-\n Actinic keratoses')
elif result[0][1] == 1:
    print('TYPE:-\n Basal cell carcinoma')
elif result[0][2] == 1:
    print('TYPE:-\n Benign keratosis-like lesions')
elif result[0][3] == 1:
    print('TYPE:-\n Dermatofibroma')
elif result[0][4] ==1 :
    print('TYPE:-\n Melanoma')
elif result[0][5] == 1:
    print('TYPE:-\n Melanocytic nevi')
elif result[0][6] == 1:
    print('TYPE:-\n Vascular lesions')
# Out:
# TYPE:-
#  Melanoma

# %%
from keras.preprocessing import image
test_image1 = image.load_img('C:/Users/Pavithra/Desktop/test2.jpg', target_size = (64, 64))
test_image1 = image.img_to_array(test_image1)
test_image1 = np.expand_dims(test_image1, axis = 0)
result = classifier.predict(test_image1)
if result[0][0] == 1:
    print('TYPE:-\n Actinic keratoses')
elif result[0][1] == 1:
    print('TYPE:-\n Basal cell carcinoma')
elif result[0][2] == 1:
    print('TYPE:-\n Benign keratosis-like lesions')
elif result[0][3] == 1:
    print('TYPE:-\n Dermatofibroma')
elif result[0][4] ==1 :
    print('TYPE:-\n Melanoma')
elif result[0][5] == 1:
    print('TYPE:-\n Melanocytic nevi')
elif result[0][6] == 1:
    print('TYPE:-\n Vascular lesions')
# Out:
# TYPE:-
#  Melanoma
